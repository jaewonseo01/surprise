# %%
import pandas as pd
outcomes_pheno = pd.read_feather('./data/mimic_outcome_pheno_binary.feather')

# %%
train = pd.read_feather('./data/mimic_outcomes_train.feather')
outcomes_pheno_train = outcomes_pheno.loc[outcomes_pheno['pid'].isin(train['pid'])]
outcomes_pheno_train.to_feather('./data/mimic_outcomes_pheno_binary_train.feather')

# %%
valid = pd.read_feather('./data/mimic_outcomes_valid.feather')
outcomes_pheno_valid = outcomes_pheno.loc[outcomes_pheno['pid'].isin(valid['pid'])]
outcomes_pheno_valid.to_feather('./data/mimic_outcomes_pheno_binary_valid.feather')

# %%
test = pd.read_feather('./data/mimic_outcomes_test.feather')
outcomes_pheno_test = outcomes_pheno.loc[outcomes_pheno['pid'].isin(test['pid'])]
outcomes_pheno_test.to_feather('./data/mimic_outcomes_pheno_binary_test.feather')

# %%
import pandas as pd
outcomes_pheno = pd.read_feather('./data/eicu_outcome_pheno_binary.feather')

# %%
train = pd.read_feather('./data/eicu_outcomes_train.feather')
outcomes_pheno_train = outcomes_pheno.loc[outcomes_pheno['pid'].isin(train['pid'])]
outcomes_pheno_train.to_feather('./data/eicu_outcomes_pheno_binary_train.feather')

# %%
valid = pd.read_feather('./data/eicu_outcomes_valid.feather')
outcomes_pheno_valid = outcomes_pheno.loc[outcomes_pheno['pid'].isin(valid['pid'])]
outcomes_pheno_valid.to_feather('./data/eicu_outcomes_pheno_binary_valid.feather')

# %%
test = pd.read_feather('./data/eicu_outcomes_test.feather')
outcomes_pheno_test = outcomes_pheno.loc[outcomes_pheno['pid'].isin(test['pid'])]
outcomes_pheno_test.to_feather('./data/eicu_outcomes_pheno_binary_test.feather')

# %%
import pandas as pd

m = pd.read_feather('./data/mimic_data_test.feather')
e =  pd.read_feather('./data/eicu_data_test.feather')
